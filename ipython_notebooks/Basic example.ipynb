# %% [markdown]
# # POPENE basic usage example
#
# POPANE dataset usage in Python with pandas module. This is a bare-minimum example of loading the data, data inspection and the simples visualization.
#
# ### Imports

# %%
import glob
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Reading the content of the datafiles
#
# List available files

# %%
paths = glob.glob('study1_sample/*.csv', recursive=True)
paths
# Out:
# ['study1_sample/S1_P1_Threat.csv',
#  'study1_sample/S1_P3_Threat.csv',
#  'study1_sample/S1_P3_Positive_Emotion_High_Approach.csv',
#  'study1_sample/S1_P2_All.csv',
#  'study1_sample/S1_P2_Neutral8.csv',
#  'study1_sample/S1_P2_Baseline.csv',
#  'study1_sample/S1_P1_Positive_Emotion_High_Approach.csv',
#  'study1_sample/S1_P3_All.csv',
#  'study1_sample/S1_P3_Baseline.csv',
#  'study1_sample/S1_P1_Baseline.csv',
#  'study1_sample/S1_P1_All.csv',
#  'study1_sample/S1_P2_Threat.csv']

# %% [markdown]
# Restric to files containing all conditions for participants no. 1, 2 & 3.

# %%
paths = [i for i in paths if 'All' in i]
paths
# Out:
# ['study1_sample/S1_P2_All.csv',
#  'study1_sample/S1_P3_All.csv',
#  'study1_sample/S1_P1_All.csv']

# %% [markdown]
# Get one of the files.

# %%
example_file = paths[0]

# %% [markdown]
# Preview the data with bash command.

# %%
# !head -n 15 $example_file
# Out:
# #Study_name,Study_1
# #Subject_ID,2
# #Subject_Age,21
# #Subject_Sex,1
# #Subject_Height,154
# #Subject_Weight,64
# #Channel_Name,timestamp,affect,ECG,EDA,temp,respiration,SBP,DBP,marker
# #Data_Category,timestamp,data,data,data,data,data,data,data,marker
# #Data_Unit,second,custom,millivolts,microsiemens,Celsius,millivolts,mmHg,mmHg,string
# #Data_Sample_rate,1000Hz,1000Hz,1000Hz,1000Hz,1000Hz,1000Hz,1000Hz,1000Hz,1000Hz
# #Data_Device,LabChart_8.19_(ADInsturments_New_Zealand),Response_Meter_(ADInsturments_New_Zealand),ECG_(ADInsturments_New_Zealand),GSR_Amp_(ADInstruments_New_Zealand),Thermistor_Pod_(ADInstruments_New_Zealand),Pneumotrace_II_(UFI_USA),Finometer_MIDI_(Finapres_Medical_Systems_Netherlands),Finometer_MIDI_(Finapres_Medical_Systems_Netherlands),Labchart_8.19_(AdInsturments_New_Zealand)
# timestamp,affect,ECG,EDA,temp,respiration,SBP,DBP,marker
# 0,5.0,3.012,0.0,33.38,0.68,121.97,108.03,
# 0.001,5.0,2.576,0.03,33.38,0.69,122.16,108.31,
# 0.002,5.0,1.762,0.17,33.38,0.7,121.0,107.84,

# %%
print(example_file)
# Out:
# study1_sample/S1_P2_All.csv

# %% [markdown]
# Read file contents into pandas' DataFrame. Skip 9 first rows, these are the header.

# %%
df = pd.read_csv(example_file, skiprows=11)
df
# Out:
#         timestamp  affect    ECG   EDA   temp  respiration     SBP     DBP  \
# 0           0.000     5.0  3.012  0.00  33.38         0.68  121.97  108.03
# 1           0.001     5.0  2.576  0.03  33.38         0.69  122.16  108.31
# 2           0.002     5.0  1.762  0.17  33.38         0.70  121.00  107.84
# 3           0.003     5.0  0.894  0.55  33.38         0.71  120.72  107.28
# 4           0.004     5.0 -0.049  1.26  33.38         0.73  121.53  107.69
# ...           ...     ...    ...   ...    ...          ...     ...     ...
# 941745    941.745     1.3  0.000   NaN  33.68         0.50   99.72   99.97
# 941746    941.746     1.3  0.021   NaN  33.68         0.50  100.19  100.31
# 941747    941.747     1.3 -0.008   NaN  33.68         0.50   99.09   99.72
# 941748    941.748     1.3 -0.032   NaN  33.68         0.50   99.22  100.06
# 941749    941.749     1.3  0.017   NaN  33.68         0.50  100.50  100.59
#
#         marker
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 941745     NaN
# 941746     NaN
# 941747     NaN
# 941748     NaN
# 941749     NaN
#
# [941750 rows x 9 columns]

# %% [markdown]
# ## Descriptive statistics
#
# Example descriptive statistics of the data frame.

# %%
df.describe()
# Out:
#            timestamp         affect            ECG            EDA  \
# count  941750.000000  941750.000000  941750.000000  912754.000000
# mean      470.874500       4.939183       0.049516      16.294775
# std       271.859952       2.691836       0.291976       1.476093
# min         0.000000       0.000000      -3.084000       0.000000
# 25%       235.437250       1.300000      -0.051000      15.360000
# 50%       470.874500       5.000000       0.010000      16.040000
# 75%       706.311750       7.500000       0.078000      17.270000
# max       941.749000       9.900000       4.044000      20.480000
#
#                 temp    respiration            SBP            DBP  \
# count  941750.000000  941750.000000  941750.000000  941750.000000
# mean       33.948250       0.961860     103.702046     109.067772
# std         0.472775       1.380919      18.680043      18.788685
# min        33.190000      -5.870000     -12.280000      -1.630000
# 25%        33.550000      -0.010000      90.190000      94.880000
# 50%        33.890000       1.150000     102.030000     108.970000
# 75%        34.410000       1.880000     115.130000     122.000000
# max        34.770000       7.310000     201.030000     201.130000
#
#               marker
# count  510003.000000
# mean       49.823856
# std        64.841542
# min        -1.000000
# 25%        -1.000000
# 50%        -1.000000
# 75%       108.000000
# max       209.000000

# %% [markdown]
# ## Plotting the dataframe

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200

df[df.columns.difference(['timestamp'])].plot(subplots=True)
plt.show()
